# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel('/content/Sample DataSet.xlsx')

# %%
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.Area, df.Price, color='red', marker='+')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
rg = linear_model.LinearRegression()

rg.fit(df[['Area']],df.Price)
rg.predict([[3600]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([669452.05479452])

# %%
m=rg.coef_

# %%
b=rg.intercept_

# %%
y=m*3600+b
y
# Out:
# array([669452.05479452])

# %%
d=pd.read_excel('/content/Predict DataSet.xlsx')
d.head()
# Out:
#    Area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p=rg.predict(d)

# %%
d['Price']=p

# %%
d.head()
# Out:
#    Area          Price
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836

# %%
d.to_excel('Predict DataSet.xlsx',index=False)

# %%
y=m*4560+b
y
# Out:
# array([799808.21917808])

# %%
# %matplotlib inline
plt.scatter(df.Area, rg.predict(df[['Area']]), color='red', marker='+')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')
